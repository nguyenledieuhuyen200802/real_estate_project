# %% [markdown]
# # 1. Explodatory Data Analysis:

# %%
pip uninstall summarytools

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
real_estate_data = pd.read_csv('batdongsan.csv')
real_estate_data.head()
# Out:
#         Loại hình nhà ở  Diện tích (m²)  Mặt tiền (m)  Mức giá (tỷ)  Số tầng  \
# 0  Nhà biệt thự liền kề           196.0           NaN          18.0      NaN
# 1  Nhà biệt thự liền kề           196.0          10.0          18.0      1.0
# 2  Nhà biệt thự liền kề           282.0           NaN          21.0      2.0
# 3  Nhà biệt thự liền kề            80.0           NaN           6.5      3.0
# 4  Nhà biệt thự liền kề           337.5          15.0          38.0      3.0
#
#    Số phòng ngủ  Số toilet       Pháp lý     Nội thất   Hướng nhà  \
# 0           NaN        NaN           NaN          NaN         NaN
# 1           3.0        3.0  Giấy tờ khác          NaN   Tây - Nam
# 2           4.0        6.0      Đã có sổ  Có nội thất   Tây - Bắc
# 3           4.0        3.0      Đã có sổ  Có nội thất         NaN
# 4           5.0        6.0      Đã có sổ  Có nội thất  Đông - Bắc
#
#   Hướng ban công  Đường vào (m)   Ngày đăng Ngày hết hạn           Loại tin  \
# ...

# %%
rows, cols = real_estate_data.shape
print('rows =', rows, '\ncols =', cols)
# Out:
# rows = 8973
# cols = 17

# %%
real_estate_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8973 entries, 0 to 8972
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Loại hình nhà ở      8973 non-null   object
#  1   Diện tích (m²)       8973 non-null   object
#  2   Mức giá (tỷ)         8972 non-null   object
#  3   Số phòng ngủ         8702 non-null   float64
#  4   Số toilet            8219 non-null   float64
#  5   Pháp lý              5866 non-null   object
#  6   Nội thất             5332 non-null   object
#  7   Hướng nhà            2755 non-null   object
#  8   Hướng ban công       2867 non-null   object
#  9   Ngày đăng            8973 non-null   object
#  10  Ngày hết hạn         8954 non-null   object
#  11  Loại tin             8973 non-null   object
#  12  Tên chung cư -> XÓA  8810 non-null   object
#  13  Đường/Phố            8312 non-null   object
#  14  Xã/Phường/Thị trấn   8820 non-null   object
# ...

# %%
real_estate_data.describe()
# Out:
#        Số phòng ngủ     Số toilet
# count    8702.000000  8219.000000
# mean        2.224201     1.898528
# std         0.936410     0.884369
# min         1.000000     1.000000
# 25%         2.000000     2.000000
# 50%         2.000000     2.000000
# 75%         3.000000     2.000000
# max        60.000000    60.000000

# %%
real_estate_data.describe(include='object')
# Out:
#         Loại hình nhà ở Diện tích (m²) Mức giá (tỷ)   Pháp lý Nội thất  \
# count              8973           8973         8972      5866     5332
# unique                2            669          701         3       63
# top     Căn hộ chung cư          70.00   Thỏa thuận  Đã có sổ   Đầy đủ
# freq               8972            357          563      3430     3162
#
#          Hướng nhà Hướng ban công   Ngày đăng Ngày hết hạn    Loại tin  \
# count         2755           2867        8973         8954        8973
# unique           8              8          69           56           4
# top     Đông - Nam     Đông - Nam  27/10/2023   06/11/2023  Tin thường
# freq           614            794         771          772        8448
#
#        Tên chung cư -> XÓA               Đường/Phố Xã/Phường/Thị trấn  \
# count                 8810                    8312               8820
# unique                1035                     466                138
# ...

# %%
real_estate_data.isnull().sum()
